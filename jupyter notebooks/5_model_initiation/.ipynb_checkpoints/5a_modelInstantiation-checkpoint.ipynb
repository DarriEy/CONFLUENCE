# %% [markdown]
# # Initializing Hydrological Models in CONFLUENCE
#
# ## Introduction
#
# This notebook guides you through the process of initializing hydrological models within the CONFLUENCE framework. Model initialization is a critical step that sets up the model structure, parameters, and initial conditions for simulation.
#
# Key steps covered in this notebook include:
#
# 1. Performing initial test runs to ensure proper setup.
# 2. Vizualise initial output.
#
# In this notebook we focus on initializing the primary model chosen for your project, but the principles can be applied to other  models as well. By the end of this notebook, your model will be fully initialized and running.

# %% [markdown]
# ## First we import the libraries and functions we need

# %%
import sys
from pathlib import Path
from typing import Dict, Any
import logging
import yaml # type: ignore

current_dir = Path.cwd()
parent_dir = current_dir.parent.parent
sys.path.append(str(parent_dir))

from utils.models_utils.model_utils import SummaRunner, MizuRouteRunner # type: ignore
from utils.report_utils.reporting_utils import VisualizationReporter

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# %% [markdown]
# ## Check configurations
#
# Now we should print our configuration settings and make sure that we have defined all the settings we need.

# %%
config_path = Path('../../0_config_files/config_active.yaml')
with open(config_path, 'r') as config_file:
    config = yaml.safe_load(config_file)
    print(f"FORCING_DATASET: {config['FORCING_DATASET']}")
    print(f"EASYMORE_CLIENT: {config['EASYMORE_CLIENT']}")
    print(f"FORCING_VARIABLES: {config['FORCING_VARIABLES']}")
    print(f"EXPERIMENT_TIME_START: {config['EXPERIMENT_TIME_START']}")
    print(f"EXPERIMENT_TIME_START: {config['EXPERIMENT_TIME_START']}")
# Out:
# FORCING_DATASET: ERA5
# EASYMORE_CLIENT: easymore cli
# FORCING_VARIABLES: longitude,latitude,time,LWRadAtm,SWRadAtm,pptrate,airpres,airtemp,spechum,windspd
# EXPERIMENT_TIME_START: 2010-01-01 01:00
# EXPERIMENT_TIME_START: 2010-01-01 01:00

# %% [markdown]
# ## Define default paths
#
# Now let's define the paths to data directories before we run the pre processing scripts and create the containing directories

# %%
# Main project directory
data_dir = config['CONFLUENCE_DATA_DIR']
project_dir = Path(data_dir) / f"domain_{config['DOMAIN_NAME']}"

# Data directoris
simulation_dir = project_dir / 'simulations' / f"{config['EXPERIMENT_ID']}"
hydro_model_dir = simulation_dir / f"{config['HYDROLOGICAL_MODEL']}"
routing_model_dir = simulation_dir / f"{config['ROUTING_MODEL']}"

# Make sure the new directories exists
hydro_model_dir.mkdir(parents = True, exist_ok = True)
routing_model_dir.mkdir(parents = True, exist_ok = True)

# %% [markdown]
# ## 1. Initalize hydrological model runs

# %%
# Initialize model specific preprocessors
if config['HYDROLOGICAL_MODEL'] == 'SUMMA':
    sr = SummaRunner(config, logger)
    mr = MizuRouteRunner(config, logger)

    spatial_results = sr.run_summa()
    streamflow_results = mr.run_mizuroute()
# Out:
# 2024-10-21 20:41:24,439 - INFO - Starting mizuRoute run
# 2024-10-21 20:55:48,264 - INFO - mizuRoute run completed successfully

# %% [markdown]
# ## 2. Vizualise results

# %%
# Initialize time series vizualiser
vr = VisualizationReporter(config, logger)

# Create visualization
model_outputs = [(f"{config['HYDROLOGICAL_MODEL']}", str(project_dir / "simulations" / config['EXPERIMENT_ID'] / "mizuRoute" / f"{config['EXPERIMENT_ID']}.h.{config['FORCING_START_YEAR']}-01-01-03600.nc"))]
obs_files = [('Observed', str(project_dir / "observations" / "streamflow" / "preprocessed" / f"{config.get('DOMAIN_NAME')}_streamflow_processed.csv"))]
plot_file = vr.plot_streamflow_simulations_vs_observations(model_outputs, obs_files)

if plot_file:
    logger.info(f"Streamflow comparison plot saved to: {plot_file}")
else:
    logger.error("Failed to create streamflow comparison plot")

# Optional: Display the plot in the notebook
from IPython.display import Image
Image(filename=plot_file)
# Out:
# [('SUMMA',                                seg  IRFroutedRunoff
# time
# 2010-01-01 00:59:59.999986688    0     3.472312e-09
# 2010-01-01 01:59:59.999986688    0     6.536610e+03
# 2010-01-01 02:59:59.999986688    0     9.469719e+03
# 2010-01-01 03:59:59.999986688    0     2.086978e+04
# 2010-01-01 04:59:59.999986688    0     2.399868e+04
# ...                            ...              ...
# 2018-12-31 18:59:59.999986688    0     1.065517e+01
# 2018-12-31 19:59:59.999986688    0     1.064966e+01
# 2018-12-31 20:59:59.999986688    0     1.064417e+01
# 2018-12-31 21:59:59.999986688    0     1.063867e+01
# 2018-12-31 22:59:59.999986688    0     1.063317e+01
#
# [78887 rows x 2 columns])]

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -------------------------
# about_time                4.2.1+computecanada
# affine                    2.4.0+computecanada
# alive-progress            3.1.5
# anyio                     4.6.0
# appdirs                   1.4.4+computecanada
# argon2_cffi               23.1.0+computecanada
# argon2_cffi_bindings      21.2.0+computecanada
# arrow                     1.3.0+computecanada
# asttokens                 2.4.1+computecanada
# async_lru                 2.0.4+computecanada
# attrs                     23.2.0+computecanada
# autograd                  1.6.2+computecanada
# babel                     2.16.0
# beautifulsoup4            4.12.3+computecanada
# bleach                    6.1.0+computecanada
# blosc2                    2.2.9
# cached-property           1.5.2
# cdo                       1.6.1
# cdsapi                    0.2.4+computecanada
# certifi                   2024.6.2
# cffi                      1.16.0+computecanada
# cftime                    1.6.2
# charset-normalizer        3.3.2
# click                     8.1.7+computecanada
# click-plugins             1.1.1+computecanada
# cligj                     0.7.2+computecanada
# cma                       3.2.2+computecanada
# coloredlogs               15.0.1+computecanada
# comm                      0.2.2+computecanada
# contourpy                 1.2.0+computecanada
# copulae                   0.7.8+computecanada
# cycler                    0.12.1+computecanada
# DateTime                  5.4
# debugpy                   1.8.6
# decorator                 5.1.1+computecanada
# defusedxml                0.7.1+computecanada
# Deprecated                1.2.14+computecanada
# dill                      0.3.9
# distlib                   0.3.7
# docutils                  0.21.2+computecanada
# easymore                  0.0.3+computecanada
# editables                 0.5
# executing                 2.1.0
# fastjsonschema            2.20.0+computecanada
# filelock                  3.12.2
# finder                    1.0.2
# fiona                     1.9.5+computecanada
# flexcache                 0.3+computecanada
# flexparser                0.3.1+computecanada
# flit_core                 3.9.0
# fonttools                 4.49.0+computecanada
# fqdn                      1.5.1+computecanada
# fsspec                    2024.9.0+computecanada
# future                    1.0.0+computecanada
# geopandas                 0.14.3
# geovoronoi                0.4.0+computecanada
# grapheme                  0.6.0+computecanada
# grass                     0.1.2
# h11                       0.14.0+computecanada
# h5py                      3.10.0
# hatch-vcs                 0.3.0
# hatchling                 1.18.0
# hs-restclient             1.3.7
# httpcore                  1.0.6
# httpx                     0.27.2
# humanfriendly             10.0+computecanada
# hydrobm                   1.0.2
# idna                      3.6
# imageio                   2.34.0
# ipykernel                 6.29.5+computecanada
# ipython                   8.28.0
# ipywidgets                8.1.5
# isoduration               20.11.0+computecanada
# jedi                      0.19.1+computecanada
# jinja2                    3.1.4+computecanada
# joblib                    1.4.2+computecanada
# json5                     0.9.22
# jsonpointer               3.0.0+computecanada
# jsonschema                4.23.0+computecanada
# jsonschema_specifications 2023.12.1+computecanada
# jupyter                   1.1.1
# jupyter_client            8.6.3
# jupyter-console           6.6.3
# jupyter_core              5.7.2+computecanada
# jupyter_events            0.10.0+computecanada
# jupyter_lsp               2.2.5+computecanada
# jupyter_server            2.14.2
# jupyter_server_terminals  0.5.3+computecanada
# jupyterlab                4.2.5
# jupyterlab_pygments       0.3.0+computecanada
# jupyterlab_server         2.27.3
# jupyterlab_widgets        3.0.13
# kiwisolver                1.4.5+computecanada
# lazy_loader               0.4+computecanada
# MarkupSafe                2.1.5+computecanada
# marshmallow               3.0.0b2
# matplotlib                3.7.2+computecanada
# matplotlib_inline         0.1.7+computecanada
# mistune                   3.0.2+computecanada
# mpi4py                    3.1.6
# mpmath                    1.3.0+computecanada
# msgpack                   1.0.8+computecanada
# multiprocess              0.70.17
# nbclient                  0.10.0+computecanada
# nbconvert                 7.16.4+computecanada
# nbformat                  5.10.4+computecanada
# ndindex                   1.7
# nest_asyncio              1.6.0+computecanada
# netCDF4                   1.6.4
# networkx                  3.3+computecanada
# notebook                  7.2.2
# notebook_shim             0.2.4+computecanada
# numexpr                   2.8.7
# numpy                     1.26.4+computecanada
# oauthlib                  3.2.2+computecanada
# overrides                 7.7.0+computecanada
# packaging                 23.1
# pandas                    2.2.2+computecanada
# pandocfilters             1.5.1+computecanada
# parso                     0.8.4+computecanada
# pathspec                  0.11.2
# patsy                     0.5.6+computecanada
# pexpect                   4.9.0+computecanada
# Pillow                    10.0.0+computecanada
# Pint                      0.24.3+computecanada
# pint-xarray               0.4
# pip                       23.2.1
# platformdirs              3.10.0
# plotly                    5.23.0
# pluggy                    1.3.0
# prometheus_client         0.21.0
# prompt_toolkit            3.0.48
# psutil                    5.9.8
# ptyprocess                0.7.0+computecanada
# pure_eval                 0.2.3+computecanada
# pvlib                     0.11.0
# py-cpuinfo                9.0.0
# pycparser                 2.22
# pygments                  2.18.0+computecanada
# pymoo                     0.6.0.1+computecanada
# pyparsing                 3.0.9+computecanada
# pyproj                    3.6.1
# pyshp                     2.3.1+computecanada
# pyswarm                   0.6
# python_dateutil           2.9.0.post0+computecanada
# python_json_logger        2.0.7+computecanada
# pytz                      2024.1+computecanada
# pyviscous                 2.2.1
# PyYAML                    6.0.1+computecanada
# pyzmq                     26.0.3+computecanada
# rapclust                  0.1.2
# rasterio                  1.3.9+computecanada
# rasterstats               0.19.0+computecanada
# referencing               0.35.1+computecanada
# requests                  2.31.0+computecanada
# requests_oauthlib         1.3.1+computecanada
# requests_toolbelt         1.0.0+computecanada
# rfc3339_validator         0.1.4+computecanada
# rfc3986_validator         0.1.1+computecanada
# rpds_py                   0.18.1+computecanada
# Rtree                     1.2.0+computecanada
# SALib                     1.5.1
# scikit_image              0.24.0+computecanada
# scikit_learn              1.5.0+computecanada
# scipy                     1.11.2+computecanada
# seaborn                   0.13.2+computecanada
# Send2Trash                1.8.3+computecanada
# setuptools                68.1.2
# setuptools-scm            7.1.0
# shapely                   2.0.2+computecanada
# simpledbf                 0.2.6
# simplejson                3.19.2+computecanada
# six                       1.16.0
# sklearn                   0.0+computecanada
# sniffio                   1.3.1+computecanada
# snuggs                    1.4.7+computecanada
# soupsieve                 2.6+computecanada
# spotpy                    1.6.2
# stack_data                0.6.3+computecanada
# statistics                1.0.3.5+computecanada
# statsmodels               0.14.3+computecanada
# sympy                     1.13.3+computecanada
# tables                    3.9.1
# tenacity                  9.0.0
# terminado                 0.18.1+computecanada
# threadpoolctl             3.5.0+computecanada
# tifffile                  2024.9.20+computecanada
# tinycss2                  1.3.0+computecanada
# tomli                     2.0.1
# torch                     2.3.1+computecanada
# tornado                   6.3.3+computecanada
# tqdm                      4.66.2+computecanada
# traitlets                 5.14.3+computecanada
# trove-classifiers         2023.8.7
# types-python-dateutil     2.9.0.20241003
# typing_extensions         4.12.2+computecanada
# tzdata                    2024.1+computecanada
# uri_template              1.3.0+computecanada
# urllib3                   2.2.1
# virtualenv                20.24.3
# wcwidth                   0.2.13+computecanada
# webcolors                 24.8.0
# webencodings              0.5.1+computecanada
# websocket_client          1.8.0+computecanada
# wheel                     0.41.2
# widgetsnbextension        4.0.13
# wrapt                     1.16.0+computecanada
# xarray                    2024.2.0
# zope.interface            6.1+computecanada
